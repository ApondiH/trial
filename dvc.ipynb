# %% [markdown]
# MATPLOTLIB TUTORIAL

# %%
from matplotlib import pylab # command for importing pylab alafu tuka print ext
print(pylab.__version__)
# Out:
# 1.21.5

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 25)
y = x * x + 2
print(x)
print(y)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
print(np.array([x,y]).reshape(25,2))
# Out:
# [[  0.           0.41666667]
#  [  0.83333333   1.25      ]
#  [  1.66666667   2.08333333]
#  [  2.5          2.91666667]
#  [  3.33333333   3.75      ]
#  [  4.16666667   4.58333333]
#  [  5.           5.41666667]
#  [  5.83333333   6.25      ]
#  [  6.66666667   7.08333333]
#  [  7.5          7.91666667]
#  [  8.33333333   8.75      ]
#  [  9.16666667   9.58333333]
#  [ 10.           2.        ]
#  [  2.17361111   2.69444444]
#  [  3.5625       4.77777778]
#  [  6.34027778   8.25      ]
#  [ 10.50694444  13.11111111]
#  [ 16.0625      19.36111111]
#  [ 23.00694444  27.        ]
#  [ 31.34027778  36.02777778]
#  [ 41.0625      46.44444444]
#  [ 52.17361111  58.25      ]
#  [ 64.67361111  71.44444444]
#  [ 78.5625      86.02777778]
#  [ 93.84027778 102.        ]]

# %%
""" it only takes one command to draw
"""
pylab.plot(x,y, 'g')

# %%
# drawing a subgraph 
pylab.subplot(1,2,1)# the contents of the brackets represent (rows,columns,indexes)
pylab.plot(x,y, 'b--') # the 3rd parameter here determines color and line style
pylab.subplot(1,2, 2)
pylab.plot(y,x, 'g--')

# %%
# drawing a subgraph
pylab.subplot(1,2,1)# the contents of the brackets represent (rows,columns,indexes)
pylab.plot(x,y, 'r--') # the 3rd parameter here determines color and line style
pylab.subplot(1,2, 1)
pylab.plot(y,x, 'g--')

# %%
pylab.subplot(1,1,1)# the contents of the brackets represent (rows,columns,indexes)
pylab.plot(x,y, 'r--') # the 3rd parameter here determines color and line style
pylab.subplot(1,2, 2)
pylab.plot(y,x, 'g--')

# %%
pylab.subplot(1,2,1)# the contents of the brackets represent (rows,columns,indexes)
pylab.plot(x,y, 'r--') # the 3rd parameter here determines color and line style
pylab.subplot(2,2, 2)
pylab.plot(y,x, 'g--')

# %%
pylab.subplot(1,2,1)# the contents of the brackets represent (rows,columns,indexes)
pylab.plot(x,y, 'r--') # the 3rd parameter here determines color and line style
pylab.subplot(1,2, 1)
pylab.plot(y,x, 'g--')

# %% [markdown]
# OPERATOR DESCRIPTION
# fig.add_axes()=initializes subplot a=fig.add_subplot(222)
# fig. b=plt.subplots(nrows=3, nclos=2)= adds subplot
# ax=plt.subplots(2,2)=creates subplot

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()

axes = fig.add_axes([0.5, 0.1, 0.8, 0.8]) #control the left,right,width,height of the canvas (from 0 to 1)

axes.plot(x,y, 'r')

# %%
#again we can draw subgraphs
fig, axes = plt.subplots(nrows= 1, ncols=2) # submap is of 1 row, 2 columns
for ax in axes:
    ax.plot(x,y, 'r')

# %%
fig, axes = plt.subplots(nrows= 1, ncols=3) # submap is of 1 row, 2 columns
for ax in axes:
    ax.plot(x,y, 'r')

# %%
fig, axes = plt.subplots(nrows= 2, ncols=3) # submap is of 1 row, 2 columns
for ax in axes:
    ax.plot(x,y, 'r')  #usijali about hiyo error juu ya graph.yake pia iko blank
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15416\2687471411.py in <module>
#       1 fig, axes = plt.subplots(nrows= 2, ncols=3) # submap is of 1 row, 2 columns
#       2 for ax in axes:
# ----> 3     ax.plot(x,y, 'r')  #usijali about hiyo error juu ya graph.yake pia iko blank
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig, axes = plt.subplots(nrows= 2, ncols=1) # submap is of 1 row, 2 columns
for ax in axes:
    ax.plot(x,y, 'r')

# %%
#we can also draw a picture or graph inside another graph
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) #big axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # small axes

axes1.plot(x,y, 'r')
axes2.plot(y, x, 'g')

# %%
fig = plt.figure(figsize=(16,9)) # new graphic object

fig.add_subplot()

plt.plot(x, y, 'r')

# %%
fig = plt.figure(figsize=(16,9), dpi=300) #dpi-dots per inch.If you want a higher quality print nothing less than 300

fig.add_subplot()

plt.plot(x, y, 'r')

# %%
fig,axes = plt.subplots(figsize=(16,9), dpi=50)
axes.plot(x,y, 'r')

# %%
# title
fig,axes = plt.subplots()
axes.set_title("Harriet's graph")
axes.plot(x,y, 'r')

# %%
fig,axes = plt.subplots()
axes.set_title("harriet's graph")
axes.set_xlabel("margaret")
axes.set_ylabel("Anne")
axes.plot(x,y, 'r')

# %%
ax.legend(["label1", "label2"])

fig,axes = plt.subplots()
axes.set_title("harriet's graph")
axes.set_xlabel("margaret")
axes.set_ylabel("Anne")
axes.plot(x, x**2)
axes.plot(x, x**3)

# %%
ax.legend(["label1", "label2"])

fig,axes = plt.subplots()
axes.set_title("harriet's graph")
axes.set_xlabel("margaret")
axes.set_ylabel("Anne")
axes.plot(x, x**2)
axes.plot(x, x**3)

axes.legend(["y=x**2", "y = x**3"], loc=2) # loc changes location of the legend

# %%
ax.legend(["label1", "label2"])

fig,axes = plt.subplots()
axes.set_title("harriet's graph")
axes.set_xlabel("margaret")
axes.set_ylabel("Anne")
axes.plot(x, x**2)
axes.plot(x, x**3)

axes.legend(["y=x**2", "y = x**3"], loc=5)

# %%
# hebu we try dpi to make it clearer
ax.legend(["label1", "label2"])

fig,axes = plt.subplots(dpi=200)
axes.set_title("harriet's graph")
axes.set_xlabel("margaret")
axes.set_ylabel("Anne")
axes.plot(x, x**2)
axes.plot(x, x**3)

axes.legend(["y=x**2", "y = x**3"], loc=2)

# %% [markdown]
# #In matplotlib, you can set other properties such as line color, transparency and more

# %%
fig, axes = plt.subplots(dpi=300)
axes.plot(x, x+1)
axes.plot(x, x+2)
axes.plot(x, x+3)

# %%
fig, axes = plt.subplots(dpi=300)
axes.plot(x, x+1, color='red')
axes.plot(x, x+2, color="green")
axes.plot(x, x+3, color="blue")

# %%
fig, axes = plt.subplots(dpi=300)
axes.plot(x, x+1, color='red', alpha=.5) #alpha inaifanya ikae see through
axes.plot(x, x+2, color="green")
axes.plot(x, x+3, color="blue")

# %%
fig, axes = plt.subplots(dpi=300)
axes.plot(x, x**2, color='red', alpha=.5)
axes.plot(x, x+2, color="green")
axes.plot(x, x+3, color="blue")

# %%
fig, axes = plt.subplots(dpi=300)
axes.plot(x, x**2, color='red', alpha=.5)
axes.plot(x, x+2, color="green", alpha=.5)
axes.plot(x, x+3, color="blue", alpha=.5) # point is you can see the point where hizo lines zinapitana

# %%
fig, ax = plt.subplots(dpi=100)

#line width
ax.plot(x, x+1, color='blue',linewidth=0.25)
ax.plot(x, x+2, color='blue', linewidth=1 )
ax.plot(x, x+3, color='blue', linewidth=1.5)
ax.plot(x, x+4,  color='blue', linewidth=2)

# %%
fig, ax = plt.subplots(dpi=100)

ax.plot(x, x+1, color="blue", lw=2, linestyle='-')
ax.plot(x, x+2, color="blue", lw=2, linestyle='_.')
ax.plot(x, x+3, color="blue", lw=2, linestyle='__')

line, = ax.plot(x, x+4, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6368\4149948705.py in <module>
#       2
#       3 ax.plot(x, x+1, color="blue", lw=2, linestyle='-')
# ----> 4 ax.plot(x, x+2, color="blue", lw=2, linestyle='_.')
#       5 ax.plot(x, x+3, color="blue", lw=2, linestyle='__')
#       6
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# ...

# %%
fig, ax = plt.subplots(dpi=100)

ax.plot(x, x+1, color='blue',marker = '+')
ax.plot(x, x+2, color='blue',marker = 's')
ax.plot(x, x+3, color='blue',marker = 'o')
ax.plot(x, x+4,  color='blue',marker = '1')

# %%
fig, ax = plt.subplots(dpi=100)

ax.plot(x, x+1, color='blue',marker = '+')
ax.plot(x, x+2, color='blue',marker = 's')
ax.plot(x, x+3, color='blue',marker = 'o')
ax.plot(x, x+4,  color='blue',marker = '1')

ax.plot(x, x+5, color="blue", marker='o', markersize=2)

# %%
fig, ax = plt.subplots(dpi=100)

ax.plot(x, x+1, color='blue',marker = '+')
ax.plot(x, x+2, color='blue',marker = 's')
ax.plot(x, x+3, color='blue',marker = 'o')
ax.plot(x, x+4,  color='blue',marker = '1')

ax.plot(x, x+5, color="blue", marker='o', markersize=10)

# %%
fig, ax = plt.subplots(dpi=100)

ax.plot(x, x+1, color='blue',marker = '+')
ax.plot(x, x+2, color='blue',marker = 's')
ax.plot(x, x+3, color='blue',marker = 'o')
ax.plot(x, x+4,  color='blue',marker = '1')

ax.plot(x, x+5, color="blue", marker='o', markersize=2)
ax.plot(x,x+6, color="blue", marker='s', markerfacecolor='red')

# %%
fig, ax = plt.subplots(dpi=100)

ax.plot(x, x+1, color='blue',marker = '+')
ax.plot(x, x+2, color='blue',marker = 's')
ax.plot(x, x+3, color='blue',marker = 'o')
ax.plot(x, x+4,  color='blue',marker = '1')

ax.plot(x, x+5, color="blue", marker='o', markersize=5)
ax.plot(x, x+6, color="blue", marker='s', markerfacecolor='red')
ax.plot(x,x+7, color="blue", marker='o', markersize=15, markerfacecolor='green')

# %%
""" Set the canvas grid and axes range
"""
fig,Axes =plt.subplots(1, 2, figsize=(10,5))

Axes[0].plot(x, x**2, x, x**3, lw=2)
Axes[0].grid(True)

# %%
fig,Axes =plt.subplots(1, 2, figsize=(10,5))

Axes[0].plot(x, x**2, x, x**3, lw=2)
Axes[0].grid(True)

Axes[1].plot(x, x**2, x, x**3, lw=2)
Axes[1].set_ylim([0,60])
Axes[1].set_xlim([2,5])
Axes[1].grid(True)

# %% [markdown]
# OTHER 2D GRAPHICS

# %%
n = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))

# %%
n = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title("scatter")
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

# %%
n = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title("scatter")
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

axes[1].set_title("step")
axes[1].step(n, n**2, lw=2)

axes[2].set_title("bar")
# Out:
# Text(0.5, 1.0, 'bar')

# %%
n = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title("scatter")
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

axes[1].set_title("step")
axes[1].step(n, n**2, lw=2)

axes[2].set_title("bar")
axes[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)
# Out:
# <BarContainer object of 6 artists>

# %%
n = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title("scatter")
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

axes[1].set_title("step")
axes[1].step(n, n**2, lw=2)

axes[2].set_title("bar")
axes[2].bar(n, n**2, align="center", width=0.5)
# Out:
# <BarContainer object of 6 artists>

# %%
n = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title("scatter")
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

axes[1].set_title("step")
axes[1].step(n, n**2, lw=2)

axes[2].set_title("bar")
axes[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)

axes[3].set_title("fill_between")
axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5)

# %%
""" Draw a radar chart
"""
fig =plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, .6, .6],polar = True)

# %%
fig =plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, .6, .6],polar = True)
t = np.linspace(0,2 * np.pi,100)
ax.plot(t,t,color='blue',lw=3)

# %%
""" Draw a histogram
"""
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,4))
axes[0].set_title("Default Histogram")
axes[0].hist(n)
# Out:
# (array([5.8000e+01, 6.6400e+02, 5.0130e+03, 1.7712e+04, 3.1895e+04,
#         2.8480e+04, 1.2841e+04, 2.9540e+03, 3.5700e+02, 2.6000e+01]),
#  array([-4.12780122, -3.2753373 , -2.42287338, -1.57040947, -0.71794555,
#          0.13451836,  0.98698228,  1.8394462 ,  2.69191011,  3.54437403,
#          4.39683794]),
#  <BarContainer object of 10 artists>)

# %%
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,4))
axes[0].set_title("Default Histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=50)
# Out:
# (array([1.0000e+00, 3.0000e+00, 8.0000e+00, 1.1000e+01, 1.9000e+01,
#         3.8000e+01, 7.1000e+01, 1.3000e+02, 2.5200e+02, 4.2100e+02,
#         6.9200e+02, 1.1170e+03, 1.7250e+03, 2.6020e+03, 3.7970e+03,
#         5.4250e+03, 7.5350e+03, 1.0244e+04, 1.3604e+04, 1.7764e+04,
#         2.2460e+04, 2.7826e+04, 3.3788e+04, 4.0281e+04, 4.7066e+04,
#         5.3919e+04, 6.0510e+04, 6.6859e+04, 7.2899e+04, 7.8338e+04,
#         8.3028e+04, 8.7025e+04, 9.0340e+04, 9.2948e+04, 9.4956e+04,
#         9.6480e+04, 9.7566e+04, 9.8403e+04, 9.8948e+04, 9.9327e+04,
#         9.9582e+04, 9.9767e+04, 9.9864e+04, 9.9933e+04, 9.9966e+04,
#         9.9985e+04, 9.9996e+04, 9.9998e+04, 9.9999e+04, 1.0000e+05]),
#  array([-4.34782138, -4.17671452, -4.00560767, -3.83450081, -3.66339395,
#         -3.49228709, -3.32118023, -3.15007338, -2.97896652, -2.80785966,
#         -2.6367528 , -2.46564594, -2.29453908, -2.12343223, -1.95232537,
# ...

# %%
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,4))
axes[0].set_title("Default Histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=5)
# Out:
# (array([   204.,  13194.,  72649.,  99049., 100000.]),
#  array([-4.56494827, -2.84332425, -1.12170022,  0.5999238 ,  2.32154782,
#          4.04317185]),
#  <BarContainer object of 5 artists>)

# %%
# Draw contour image
from matplotlib import pylab
import numpy as np
import matplotlib.cm as cm # colourmaps
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X-1)**2 - (Y - 1)**2)
Z = (Z1 - Z2)*2

print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=1, fontsize=10)
ax.set_title('contour map')
# Out:
# Text(0.5, 1.0, 'contour map')

# %%
# Draw 3D surface image
from mpl_toolkits.mplot3d  import Axes3D

fig = plt.figure(figsize=(14,6))

# %%
# Draw 3D surface image
from mpl_toolkits.mplot3d  import Axes3D

fig = plt.figure(figsize=(14,6))

# specify the 3D graphics to draw, with projections '3d'
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_surface(X,  Y, Z,  rstride=4, cstride=4, linewidth=0)

# %%
# heatmap... color map

# %% [markdown]
# Practice Example
# Write a python programming to create a pie chart of the popularity of programming languages
